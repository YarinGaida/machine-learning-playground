# %% [markdown]
# <a href="https://colab.research.google.com/github/YarinGaida/machine-learning-playground/blob/main/University-Ex/Exercise_01%20/code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
print("what")
